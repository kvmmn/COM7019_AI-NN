# %%
from sklearn.datasets import make_classification
from sklearn.model_selection import train_test_split
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np

# %%
X, y = make_classification(n_samples=10000, n_informative=2, random_state=274)

# %%
# Splitting the data set into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=274)

# %%
# print the training and testing data shapes
print("Training data shape:", X_train.shape, y_train.shape)
print("Testing data shape:", X_test.shape, y_test.shape)
# Out:
# Training data shape: (8000, 20) (8000,)
# Testing data shape: (2000, 20) (2000,)

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Dense(10, activation="relu", input_shape=(X_train.shape[1],)),
    tf.keras.layers.Dense(10, activation="relu"),
    tf.keras.layers.Dense(1, activation="sigmoid")
])

model.compile(optimizer="adam", loss="binary_crossentropy", metrics=["accuracy"])

history = model.fit(X_train, y_train, epochs=20, validation_data=(X_test, y_test), verbose=1)
# Out:
# Epoch 1/20
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6894 - loss: 0.5919 - val_accuracy: 0.8210 - val_loss: 0.4375
# Epoch 2/20
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8546 - loss: 0.3564 - val_accuracy: 0.8535 - val_loss: 0.3462
# Epoch 3/20
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8666 - loss: 0.3191 - val_accuracy: 0.8605 - val_loss: 0.3314
# Epoch 4/20
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8689 - loss: 0.3104 - val_accuracy: 0.8655 - val_loss: 0.3233
# Epoch 5/20
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8698 - loss: 0.3061 - val_accuracy: 0.8670 - val_loss: 0.3193
# Epoch 6/20
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8712 - loss: 0.3031 - val_accuracy: 0.8705 - val_loss: 0.3167
# Epoch 7/20
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8721 - loss: 0.3011 - val_accuracy: 0.8695 - val_loss: 0.3131
# Epoch 8/20
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8734 - loss: 0.2989 - val_accuracy: 0.8680 - val_loss: 0.3133
# Epoch 9/20
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8742 - loss: 0.2971 - val_accuracy: 0.8670 - val_loss: 0.3083
# Epoch 10/20
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8744 - loss: 0.2962 - val_accuracy: 0.8705 - val_loss: 0.3105
# Epoch 11/20
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8740 - loss: 0.2949 - val_accuracy: 0.8710 - val_loss: 0.3077
# Epoch 12/20
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8756 - loss: 0.2939 - val_accuracy: 0.8690 - val_loss: 0.3048
# Epoch 13/20
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8767 - loss: 0.2929 - val_accuracy: 0.8725 - val_loss: 0.3070
# Epoch 14/20
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8735 - loss: 0.2928 - val_accuracy: 0.8700 - val_loss: 0.3036
# Epoch 15/20
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8752 - loss: 0.2916 - val_accuracy: 0.8700 - val_loss: 0.3073
# Epoch 16/20
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8749 - loss: 0.2913 - val_accuracy: 0.8695 - val_loss: 0.3036
# Epoch 17/20
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8763 - loss: 0.2909 - val_accuracy: 0.8700 - val_loss: 0.3037
# Epoch 18/20
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8767 - loss: 0.2904 - val_accuracy: 0.8730 - val_loss: 0.3032
# Epoch 19/20
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8759 - loss: 0.2898 - val_accuracy: 0.8685 - val_loss: 0.3021
# Epoch 20/20
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8774 - loss: 0.2892 - val_accuracy: 0.8705 - val_loss: 0.3027

# %%
# plot the loss f the model
fig, ax = plt.subplots(figsize=(12, 8))
plt.plot(history.history["loss"], label="train_loss")
plt.plot(history.history["val_loss"], label="val_loss")
plt.title("Model Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.xticks(np.arange(0, 21, 1))
plt.legend(['train', 'test'], loc='upper right')
plt.show()
